# %%
import sklearn
import numpy as np
import pandas as pd
from tensorflow.keras.preprocessing.text import Tokenizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB

# %%
df = pd.read_csv('DfFinal.csv')

# %%
df[2:]
# Out:
#      personalities                                              posts  tri  \
# 2             INFJ  half go straight chariti anoth quarter go stra...    2
# 3             INFJ  im good hous unscath yeah theyr pretti terribl...    1
# 4             INFJ  depend group past without awar id come bang li...    1
# 5             INFJ  infj found mean career nurs extrem high level ...    2
# 6             INFJ  philosophi religion much els http www youtub c...    2
# ...            ...                                                ...  ...
# 4795          ESTJ  mausi girl awesom read realli hit home mani wa...    4
# 4796          ESTJ  let tri answer point bold dont know real situa...    4
# 4797          ESTJ  intjisfpthey taught live liehav notic pattern ...    2
# 4798          ESTJ  fellow artist apolog fail acknowledg poetic si...    2
# 4799          ESTJ  peopl prioriti sound like know id say enjoy fr...    1
#
#       friend  work  use  time  peopl  want  need  ...  person  ive  never  \
# 2          5     0    2     3      8     1     5  ...       2    3      1
# 3          2     0    4     3      6     4     4  ...       0    5      2
# 4          2     2    1     0      0     1     2  ...       2    3      1
# 5          2     6    4     3     10     2     2  ...       1    4      1
# 6          3     3    4     7      4     1     1  ...       5    5      3
# ...      ...   ...  ...   ...    ...   ...   ...  ...     ...  ...    ...
# 4795       2     4    2     0      3     4     3  ...       4    8      1
# 4796       2     4    2     1      3     6     1  ...       5    0      0
# 4797       2     0    1     2      9     1     0  ...       0    0      4
# 4798       0     0    1     3      1     3     3  ...       1    0      0
# 4799       5     7    2     2     10     5     3  ...       6    7      0
#
#       way  see  realli  type  thing  say  total_word_count
# 2       3    4       3     4      2    4               631
# 3       0    2       4     6      3    2               769
# 4       2    3       2     4      2    1               696
# 5       1    2       5     0      3    0               521
# 6       4    3       7     2      4    1               696
# ...   ...  ...     ...   ...    ...  ...               ...
# 4795    3    1       5     2      6    3               653
# 4796    1    8       1     3      4    3               731
# 4797    3    4       0     5      1    5               463
# 4798    1    5       0     2      0    8               656
# 4799    4    3       1     7      5    5               722
#
# [4798 rows x 32 columns]

# %%
headers = [col for col in df.columns]
headers[1:]
# Out:
# ['posts',
#  'tri',
#  'friend',
#  'work',
#  'use',
#  'time',
#  'peopl',
#  'want',
#  'need',
#  'good',
#  'well',
#  'feel',
#  'im',
#  'dont',
#  'make',
#  'much',
#  'someth',
#  'go',
#  'lot',
#  'thank',
#  'love',
#  'person',
#  'ive',
#  'never',
#  'way',
#  'see',
#  'realli',
#  'type',
#  'thing',
#  'say',
#  'total_word_count']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(df[headers[2:]], df.personalities, test_size=0.3, random_state=88)

# %%
model = MultinomialNB()
model.fit(X_train, Y_train)
# Out:
# MultinomialNB()

# %%
#Gather confidence scores!!!
# Out:
# Text sequences:
#  (4800, 908)
#
# Labels:
#  (4800,)
#
# Max sequence length:
#  908
#
# Vocab length:
#  10000
#
# Label mapping:
#  {'INFP': 0, 'INFJ': 0, 'INTP': 0, 'INTJ': 0, 'ISFP': 0, 'ISFJ': 0, 'ISTP': 0, 'ISTJ': 0, 'ENFP': 1, 'ENFJ': 1, 'ENTP': 1, 'ENTJ': 1, 'ESFP': 1, 'ESFJ': 1, 'ESTP': 1, 'ESTJ': 1}
